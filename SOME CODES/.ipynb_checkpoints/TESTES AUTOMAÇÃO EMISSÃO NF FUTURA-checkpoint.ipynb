# %% [markdown]
# #### OBSERVAÇÕES DESSAS AUTOMAÇÕES NO WORD NA ÁREA DE TRABALHO E NO CAMINHO ONDE TEM AS FOTOS DOS WHILES

# %%
import py
import pyautogui
import time
import pyperclip

fim = "Seu código foi finalizado."
inicio = "Seu código irá iniciar. Pare de usar o computador"
img = pyautogui.locateOnScreen('google.png', confidence=0.9)
img_1 = pyautogui.locateOnScreen('compliance_1.png', confidence=0.9)
img_2 = pyautogui.locateOnScreen('compliance_2.png', confidence=0.9)
img_3 = pyautogui.locateOnScreen('compliance_3.png', confidence=0.9)

pyautogui.alert(inicio)


time.sleep(1)
pyautogui.press('win')
time.sleep(2.0)
pyautogui.write('google')
time.sleep(2.0)
pyautogui.press('enter')
while img == None:
    img = pyautogui.locateOnScreen('google.png')
    time.sleep (1.0)
    print("still haven't found the image google")
pyperclip.copy(r"https://brmalls.compliancefiscal.com.br/complianceEnterpriseServer/login.seam?cid=169")
time.sleep(1.0)
pyautogui.hotkey('ctrl', 'v')
time.sleep(1.0)
pyautogui.press('enter')
while img_1 == None:
    img_1 = pyautogui.locateOnScreen('compliance_1.png')
    time.sleep (1.0)
    print("still haven't found the image 1")
pyautogui.click(x=947, y=620)
time.sleep(1.0)
while img_2 == None:
    img_2 = pyautogui.locateOnScreen('compliance_2.png')
    time.sleep (1.0)
    print("still haven't found the image 2")
pyautogui.moveTo(x=285, y=198)
time.sleep(2.0)
pyautogui.moveTo(x=350, y=246)
time.sleep(2.0)
pyautogui.click(x=662, y=354)
time.sleep(2.0)
while img_3 == None:
    img_3 = pyautogui.locateOnScreen('compliance_3.png')
    time.sleep (1.0)
    print("still haven't found the image 3")


pyautogui.alert("Seu código já chegou na parte de emitir NF's")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 19>()
#      17 pyautogui.press('win')
#      18 time.sleep(2.0)
# ---> 19 pyautogui.write('google')
#      20 time.sleep(2.0)
#      21 pyautogui.press('enter')
#
# File ~\Anaconda3\lib\site-packages\pyautogui\__init__.py:599, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     597 failSafeCheck()
#     598 returnVal = wrappedFunction(*args, **kwargs)
# --> 599 _handlePause(kwargs.get("_pause", True))
#     600 return returnVal
#
# File ~\Anaconda3\lib\site-packages\pyautogui\__init__.py:643, in _handlePause(_pause)
#     641 if _pause:
#     642     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 643     time.sleep(PAUSE)
#
# KeyboardInterrupt:

# %%
import pandas as pd



def corrigir_cnpjs(cnpj):
    cnpj = cnpj.replace('/','').replace('-','').replace('.','')
    return cnpj


def formatar(valor):
    return "{:,.2f}".format(valor)


tabela = pd.read_excel("BASE DE DADOS.NF.TESTE.xlsx")


tabela['CNPJ'] = tabela['CNPJ'].astype(str)

tabela['CNPJ'] = tabela['CNPJ'].apply(corrigir_cnpjs)

tabela['VALOR'] = tabela['VALOR'].apply(formatar)


display(tabela)
## SE ALGUMA NF TIVER O CADASTRO COM CPF, PRECISO EMITIR MANUALMENTE. ##
## SE ALGUMA NF TIVER O CADASTRO COM CPF, PRECISO EMITIR MANUALMENTE. ##
## SE ALGUMA NF TIVER O CADASTRO COM CPF, PRECISO EMITIR MANUALMENTE. ##
# Out:
#     CODIGO    RPS      VALOR            CNPJ    DESCRIÇÃO NF
# 0   123456  12345  22,110.80  11234567891011  DESCRIÇÃO NF'S
# 1   123456  12345  34,333.33  11234567891011  DESCRIÇÃO NF'S
# 2   123456  12345  10,000.00  11234567891011  DESCRIÇÃO NF'S
# 3   123456  12345   2,496.25  11234567891011  DESCRIÇÃO NF'S
# 4   123456  12345   5,515.12  11234567891011  DESCRIÇÃO NF'S
# 5   123456  12345   5,650.77  11234567891011  DESCRIÇÃO NF'S
# 6   123456  12345   2,647.06  11234567891011  DESCRIÇÃO NF'S
# 7   123456  12345  12,393.22  11234567891011  DESCRIÇÃO NF'S
# 8   123456  12345  11,266.56  11234567891011  DESCRIÇÃO NF'S
# 9   123456  12345  14,000.00  11234567891011  DESCRIÇÃO NF'S
# 10  123456  12345   6,800.00  11234567891011  DESCRIÇÃO NF'S
# 11  123456  12345  13,500.00  11234567891011  DESCRIÇÃO NF'S
# 12  123456  12345   6,751.57  11234567891011  DESCRIÇÃO NF'S
# 13  123456  12345   1,104.00  11234567891011  DESCRIÇÃO NF'S

# %% [markdown]
# #### OBSERVAÇÕES DESSAS AUTOMAÇÕES NO WORD NA ÁREA DE TRABALHO E NO CAMINHO ONDE TEM AS FOTOS DOS WHILES

# %%
###### import pyautogui
## SE ALGUMA NF TIVER O CADASTRO COM CPF, PRECISO EMITIR MANUALMENTE. ##
pyautogui.alert("Seu código irá iniciar a emissão das NFs.")
time.sleep(2.0)


for i, codigo in enumerate(tabela["CODIGO"]):
    rps = tabela.loc[i, "RPS"]
    valor = tabela.loc[i, "VALOR"]
    cnpj = tabela.loc[i, "CNPJ"]
    descricao = tabela.loc[i, "DESCRIÇÃO NF"]
  
    pyautogui.click(x=227, y=496)
    time.sleep(1.0)
    img_4 = pyautogui.locateOnScreen('compliance_5.png', confidence=0.9)
    while img_4 == None:
        img_4 = pyautogui.locateOnScreen('compliance_5.png')
        time.sleep (1.0)
        print("still haven't found the image 5")
    pyautogui.click(x=488, y=301)
    time.sleep(2.5)
    pyautogui.write(str(codigo))
    time.sleep(2.5)
    pyautogui.hotkey('tab')
    time.sleep(2.5)
    pyautogui.click(x=739, y=360, clicks=2)
    time.sleep(2.5)
    pyautogui.write(str(rps))
    time.sleep(2.5)
    pyautogui.hotkey('tab')
    time.sleep(3.0)
    pyautogui.click(x=536, y=417, clicks=2)
    time.sleep(3.0)
    pyautogui.write(str(valor))
    time.sleep(3.0)
    pyautogui.hotkey('tab')
    time.sleep(3.0)
    pyautogui.click(x=1182, y=421)
    time.sleep(3.0)
    pyautogui.click(x=1125, y=464)
    time.sleep(3.0)
    pyautogui.click(x=482, y=477)
    time.sleep(3.0)
    pyautogui.write(str(cnpj))
    time.sleep(3.0)
    pyautogui.hotkey('tab')
    time.sleep(2.5)
    pyautogui.click(x=846, y=582, clicks=3)
    time.sleep(3.0)
    pyautogui.hotkey('delete')
    time.sleep(3.0)
    pyautogui.write(descricao)
    time.sleep(3.0)
    pyautogui.hotkey('tab')
    time.sleep(3.0)
    pyautogui.click(x=1462, y=865)
    time.sleep(1.0)
    img_6 = pyautogui.locateOnScreen('compliance_6.png', confidence=0.9)
    while img_6 == None:
        img_6 = pyautogui.locateOnScreen('compliance_6.png')
        time.sleep(1.0)
        print("still haven't found the image 6")
    pyautogui.click(x=947, y=582)
    time.sleep(2.0)
    pyautogui.click(x=1397, y=863)
    time.sleep(1.0)
    img_6 = pyautogui.locateOnScreen('compliance_6.png', confidence=0.9)
    while img_6 == None:
        img_6 = pyautogui.locateOnScreen('compliance_6.png')
        time.sleep(1.0)
        print("still haven't found the image 6")
    pyautogui.click(x=947, y=582)
    time.sleep(2.0)
    pyautogui.click(x=1503, y=235)
    time.sleep(1.0)
# Out:
# still haven't found the image 5
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 5
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6
# still haven't found the image 6

# %%
pyautogui.position()
# Out:
# Point(x=947, y=580)

# %%
time.sleep(2.0)
pyautogui.alert(fim)
