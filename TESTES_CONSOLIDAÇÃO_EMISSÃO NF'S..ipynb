# %% [markdown]
# ### Coisas a adicionar ->

# %%
#teste p calcular horas do processo:start = time.time()
            #time.sleep(120)
            #end = time.time()
            #calculate_min = start - end
            #calculate_min = calculate_min/60
            #calculate_hor = start - end
            #calculate_min = calculate_min/3600
            #print(calculate_xxx)
            
####muita coisa p poder tbm organizar aqui!!!            
            
            
###fazer a automação das posições por imagens. Já tem um exemplo nesse caminho de como fazer isso.
###vou precisar de tempo, mas é uma coisa muito útil para o meu código. nas movimentações principais
### isso é importante, comom no oracle, na hora de salvar nf's...


####muitas coisas a melhorar na hora de salvar, seja p achar pastas, mexer nas pastas e mexer no arquivo que salva
#### as nf's. muitas melhorias lá.
###além, de claro, criar o projeto de salvar diretamente na proposta.

#Além de dar p achar as propostas e anexar como anotado nas observações achando x e y pôr png (vai mudar mes a mes) e então
#diminuindo a varíavel x (ou y, n lembro) e ai alinho o mouse p anexar a NF e pôr um while
#deu ruim essa ideia de cima, preciso descobrir agora como ir na linha igual mesmo,
#não sei mesmo, mas preciso achar um jeito de ir alinhado na posição de JAN.
#até ver se tá anexado c imagens mudando mensalmente essas imagens.: (já adiantei algumas abaixo)
#import pyautogui
#x, y= pyautogui.locateCenterOnScreen("5.jpg")
#pyautogui.moveTo(x, y, duration = 0.1)
#pyautogui.leftClick()

### da p abrir pastas diretamente com os codigos do modulo de (os).
###tem exemplos em outro arquivo PY nesses caminhos. dá para abrir toda vez que salvar
### as pastas ou salvar os caminhos e anexar numa outra carga p eu conseguir
###salvar esses caminhos nas cargas e automatizar na hora de anexar nas propostas.
###fechar com ctrl T (ou w - n lembro) e ai fico nessa rodagem

###COMEÇAR A GRAVAR HORÁRIO E GRAVAR TELA DE 
#QUANDO ROBO TIVER RODANDO P PEGAR OS MOTIVOS DOS POSSÍVEIS ERRROS QUE ACONTECEM NO ROBO.###

###FAZER A SITUAÇÃO NA HORA DE SALVAR AS NF’S NAS PROPOSTAS 
##*POIS O TEMPO DE DEMORAR FOR X VAI TER Q FECHAR ABA DO COMPLIANCE (IF P ISSO) 
#POIS O COMPLIANCE FECHA SOZINHO DPS DE UM TEMPO COMO INATIVO OUTRO PONTO É MELHORAR AS LOCALIZAÇÕES DE PASTAS,
#TALVEZ ATE EXCLUIR ESSA PARTE DA PROCESSO DE SALVAR AS PASTAS Q DEVEM TER AS NF’S, A GNT MSM MANUALMENTE FZR ISSO,
#SÓ FZR O FATO DE SALVAR DIRETO NA PROPOSTA, AI VALE A PENA, AGR SALVAR A PASTA ACHO Q PERDE MUITO E É MUITO PERIGOSO.###




#### *** VER SOBRE TIRAR A PARTE DO PROCESSO DE TER QUE SALVAR EM ACESSO RÁPIDO AS PASTAS DOS CLIENTES QUE
#### TEMOS QUE SALVAR AS NF'S NAS PASTAS. TALVEZ FAZER ISSO MANUALMENTE OU TENTAR VER SE CONSIGO SALVAR SO O CAMINHO
#### E PÔR NA PLANILHA. TALVEZ DÊ, MAS IDEAL É EXCLUIR ISSO DO ROBÔ, SÓ DEIXAR NO CAMINHO QUE JÁ CRIO MESMO.
#### OUTRO PONTO É PÔR UM LIMITE DO WHILE EM ALGUNS PROCESSOS EM ESPECÍFICO COM DUAS CONDIÇÕES. 
#### FAZER UM LIMITANTE, POR EXEMPLO, LIMITANTE 20 DPS DISSO O WHILE NÃO RODA MAIS E ELE REFAZ O PROCESSO OU PULA 
#### ESSE MESMO PROCESSO, SLA, POR EXEMPLO, NA HORA DE EMITIR A NF FZR UM IF P VER SE O LIMITANTE > 20 ELE VAI FECHAR O 
#### COMPLIANCE E REENICIAR O CODE ATRAVÉS DESSE IF E NESSE IF VOU TER Q POR ANOTAÇÃO TBM NA PLANILHA QUE ESSA NF EM 
#### ESPECÍFICO FOI SKIPADA P DPS REFAZER E ENTENDER O PORQUE, TALVEZ ATÉ QUANDO TIVER GRAVANDO COMO É A IDEIA QUE TENHO
#### DE IR GRAVANDO TODO O PROCESSO! ***


###### OUTRO PONTO É SEMPRE OLHAR OS CÓDIGOS, MESMO INDO AUTOMATICAMENTE P PEGAR POSSÍVEIS GAPS E MELHORIAS.
###### WORD DE OBSERVAÇÕES SEMPRE TEM PONTOS POSSÍVEIS DE MELHORIAS DESSE PROCESSO.

##### APAGAR AS OUTRAS PLAN INUTEIS QUANDO ESSA NOVA CONSOLIDAÇÃO FOR FINALIZADA.

###### SEMPRE OBSERVAR SE NA DESCRIÇÃO CONSTA ALGUM "\T", SE TIVER, VAI PULAR LINHA.
###### ISSO OCORRE MUITO AO PÔR A DESCRIÇÃO MANUALMENTE QUANDO TEM MAIS DE UMA LINHA.
###### AS QUE PEGO NO HISTÓRICO, NÃO OCORRE ISSO. NÃO DAR MOLE!!


### DÁ PARA ABRIR  O MÓDULO DE ABRIR PASTAS PELO CAMINHO EM VEZ DE FICAR CLICANDO PROPRIAMENTE LÁ ###
### TALVEZ ATÉ SALVAR CAMINHO EM VARIÁVEIS DAS PASTAS QUE VOU TER Q SALVAR AS NF'S E SALVAR DPS ###
### E USAR ESSA BASE C ESSAS VARÍAVEIS P PÔR OS CAMINHOS P VERIFICAR E TB P EXTRAIR AS NOTAS ###





#### FAZER TODOS OS WHILES COM CONDIÇÕES DE REPETIÇÕESNA EMISSÃO, POR EXEMPLO, SE O CARA RODA
#O WHILE 15 VEZES NAQUELE LOOP DO FOR ELE TEM QUE DAR UM QUIT. ELE VAI DAR UM SKIP,
#MAS A VARIAVEL NUMERO ESTIVER 15, NO IF Q VAI TER APÓS O WHILE, TEM Q ALERTAR E SAIR DO CODE, 
#SENÃO SEGUE. ASSIM EU EVITO GAPS DE UM WHILE INFINITO E ATE MESMO TEM A MENSAGEM DIZENDO QUE ALGO 
#OCORREU ERRADO NO CODE E AI ELE PARA MESMO ASSIM EM VEZ DO LOOP FICAR INIFITO. SÓ PÔR MAIS DE UMA CONDICIONAL.###

# %%
import py
import pyautogui
import time
import pyperclip
import pandas as pd
from datetime import date


fim = "Seu código foi finalizado."
inicio = "Seu código irá iniciar. Pare de usar o computador"


            
pyautogui.alert(inicio)

def locate_picture(file):
    picture = pyautogui.locateOnScreen(file, confidence=0.8)
    while picture == None:
        picture = pyautogui.locateOnScreen(file, confidence=0.8)
        time.sleep(1.0)
        print("still haven't found the file: " + file)
    return

def click_position(file):
    x, y = pyautogui.locateCenterOnScreen(file)
    time.sleep(1.0)
    clicar = pyautogui.click(x, y , duration = 0.1)
    return clicar


file_1 = 'google.png'
file_2 = 'compliance_1.png'
file_3 = 'compliance_2.png'
file_4 = 'compliance_3.png'
file_5 = 'compliance_5.png'
file_6 = 'compliance_16.png'
file_7 = 'compliance_13.png'
file_8 = 'compliance_6.png'
file_9 = 'compliance_14.png'
file_10 = 'compliance_6.png'
file_11 = 'compliance_2.png'
file_12 = 'compliance_4.png'
file_13 = 'google.png'
file_14 = 'oracle_1.png'
file_15 = 'oracle_2.png'
file_16 = 'oracle_3.png'
file_17 = 'compliance_7.png'
file_18 = 'oracle_5.png' 
file_19 = 'compliance_8.png'
file_20 = 'pasta_1.png'
file_21 = 'pasta_2.png'
file_22 = 'pasta_3.png'
file_23 = 'compliance_12.png'
file_24 = 'compliance_9.png'
file_25 = 'NF_1.png'
file_26 = 'NF_2.png'
file_27 = 'NF_3.png'
file_28 = 'NF_4.png'
file_29 = 'NF_5.png'
file_30 = 'oracle_6.png' 
file_31 = 'oracle_click_2.png'

#file_clicar_1 = 'oracle_click_1.png' inutil pois n sei o dia das transações
#file_clicar_2 = 'oracle_click_2.png'  
#file_clicar_3 = 'NF_click_1.png'
file_clicar_4 = 'NF_click_2.png'


time.sleep(1)
pyautogui.press('win')
time.sleep(1.5)
pyautogui.write('google')
time.sleep(1.5)
pyautogui.press('enter')
locate_picture(file_1)
pyperclip.copy(r"https://brmalls.compliancefiscal.com.br/complianceEnterpriseServer/login.seam?cid=169")
time.sleep(1.0)
pyautogui.hotkey('ctrl', 'v')
time.sleep(1.0)
pyautogui.press('enter')
locate_picture(file_2)
pyautogui.click(x=947, y=620)
time.sleep(1.0)
locate_picture(file_3)
pyautogui.moveTo(x=285, y=198)
time.sleep(1.5)
pyautogui.moveTo(x=350, y=246)
time.sleep(1.5)
pyautogui.click(x=662, y=354)
time.sleep(1.5)
locate_picture(file_4)
# Out:
# still haven't found the file: google.png
# still haven't found the file: compliance_1.png
# still haven't found the file: compliance_2.png
# still haven't found the file: compliance_2.png
# still haven't found the file: compliance_2.png
# still haven't found the file: compliance_3.png
# still haven't found the file: compliance_3.png

# %%
#from datetime import date

#hoje = date.today()

#hoje = hoje.strftime('%d/%m/%Y')
#hoje = str(hoje)
#hoje = hoje.replace("-", "/")
#final_ano = hoje[-2:]
#hoje = hoje[:-4] + final_ano

#print(final_ano)
#print(hoje)

#inutil p esse code, pois não sei o dia da transação.

# %%
#pôr os cnpjs sem barras, pontos e hífens, pois no sistema do compliance é necessário.
def corrigir_cnpjs(cnpj):
    cnpj = cnpj.replace('/','').replace('-','').replace('.','')
    return cnpj
#ignorar possíveis espaços no dataframe que podem interferir na descrição da NF.
def corrigir_tabs(tabs):
    tabs = tabs.replace('\t',' ').replace('\n',' ').replace('\r', ' ').replace('\0', ' ').replace('\a', ' ').replace('\b', ' ').replace('\f', ' ')
    return tabs#essa linha de codigo funciona mesmo se por ventura escreverem algo desses caracteres lá dentro.
                #ele so funcionara qnd de fato ele ''possivelmente escrevesse um tab na hrda descriçao mesmo''
                #se manualmente eu escrevi algo disso, como por exemplo em uma descrição é possivel ter
                #\0, ele não vai usar o replace.

#formatar valores por milhar de acordo com o sistema do compliance.
def formatar(valor):
    return "{:,.2f}".format(valor)



tabela = pd.read_excel("BASE DE DADOS.NF_TESTE.xlsx")

display(tabela)#antes da funções de formatação

tabela['CNPJ'] = tabela['CNPJ'].astype(str)

tabela['CNPJ'] = tabela['CNPJ'].apply(corrigir_cnpjs)

tabela['NF'] = tabela['NF'].astype(str)

tabela['VALOR'] = tabela['VALOR'].apply(formatar)

tabela['DESCRIÇÃO NF'] = tabela['DESCRIÇÃO NF'].apply(corrigir_tabs)#ESSA É A NOVA FUNÇÃO P TIRAR O \T Q AS VEZES VEM.


display(tabela)

print('-' * 15)

print(tabela.info())
# Out:
#    CODIGO    RPS     VALOR                CNPJ  \
# 0  172501  11240   2272.62  44.810.398/0001-05
# 1  172501  11683   5247.12  03.783.850/0001-00
# 2  172501  11771  32666.67  34.647.363/0002-16
# 3  172501  11846  18229.00  07.639.431/0001-41
# 4  172501  10958  14000.00  37.526.019/0002-67
# 5  172501  11756   6015.34  62.596.408/0051-94
# 6  172501  11751  27900.00  34.075.739/0001-84
# 7  172501  11766   6781.87  05.423.963/0163-87
# 8  172501  11758   5359.20  48.628.366/0001-36
#
#                                         DESCRIÇÃO NF  TRANSAÇÃO  PROPOSTA  NF  \
# 0  MIDIA DIGITAL - STEFANINI - PEDIDO DE INSERCAO...    1886033    134287 NaN
# 1  MIDIA DIGITAL - SENAI - REF PI:020416 - SHOPPI...    1944035    134683 NaN
# 2  MIDIA DIGITAL - PB CURSO - CARTA ACORDO - SHOP...    1965033    135161 NaN
# 3   MIDIA DIGITAL - SESI - REF PI: 9684 - SHOPPIN...    1974033    135298 NaN
# 4  CAMPANHA: QUINTAL SESC DADOS BANCARIOS: AG: 30...    1848042    133643 NaN
# ...

# %%
time.sleep(2.0)
pyautogui.alert("Seu código irá iniciar a emissão das NFs.")
time.sleep(1.0)


for i, codigo in enumerate(tabela["CODIGO"]):
    rps = tabela.loc[i, "RPS"]
    valor = tabela.loc[i, "VALOR"]
    cnpj = tabela.loc[i, "CNPJ"]
    descricao = tabela.loc[i, "DESCRIÇÃO NF"]
  
    pyautogui.click(x=227, y=496)
    time.sleep(1.0)
    locate_picture(file_5)
    pyautogui.click(x=488, y=301)
    time.sleep(1.5)
    pyautogui.write(str(codigo))
    time.sleep(1.5)
    pyautogui.hotkey('tab')
    locate_picture(file_6)
    pyautogui.click(x=739, y=360, clicks=2)
    time.sleep(1.5)
    pyautogui.write(str(rps))
    time.sleep(1.5)
    pyautogui.hotkey('tab')
    time.sleep(1.5)
    pyautogui.click(x=536, y=417, clicks=2)
    time.sleep(1.5)
    pyautogui.write(str(valor))
    time.sleep(1.5)
    pyautogui.hotkey('tab')
    time.sleep(1.5)
    pyautogui.click(x=1182, y=421)
    time.sleep(1.5)
    pyautogui.click(x=1125, y=464)
    time.sleep(1.5)
    pyautogui.click(x=482, y=477)
    time.sleep(1.5)
    pyautogui.write(str(cnpj))
    time.sleep(1.5)
    pyautogui.hotkey('tab')
    time.sleep(2.5)
    pyautogui.moveTo(x=1182, y=421)
    time.sleep(1.0)
    img_6 = pyautogui.locateOnScreen('compliance_15.png', confidence=0.9)
    time.sleep(1.0)
    if not img_6 == None:
        pyautogui.alert('Cadastro inexistente')
        break
    else:
        pass
    time.sleep(1.5)
    pyautogui.click(x=846, y=582, clicks=3)
    time.sleep(1.5)
    pyautogui.hotkey('delete')
    time.sleep(1.5)
    pyautogui.write(descricao)
    time.sleep(1.5)
    pyautogui.hotkey('tab')
    #AS PARTES ABAIXO ESTÃO QUE COMENTADAS COM ASTERISCO (*) SERVEM P TIRAR QND FOR TESTAR
    locate_picture(file_7)#  ****  
    #img_7 = pyautogui.locateOnScreen('compliance_13.png', confidence=0.9)
    #while img_7 == None:
        #img_7 = pyautogui.locateOnScreen('compliance_13.png')
        #time.sleep(1.0)
        #print("still haven't found the image 7")
    pyautogui.click(x=1462, y=865)#  ****   
    time.sleep(1.0)#  ****   
    locate_picture(file_8)#  ****   
    #img_8 = pyautogui.locateOnScreen('compliance_6.png', confidence=0.9)
    #while img_8 == None:
        #img_8 = pyautogui.locateOnScreen('compliance_6.png')
        #time.sleep(1.0)
        #print("still haven't found the image 8")
    pyautogui.click(x=947, y=582)#  ****   
    time.sleep(1.5)#  ****   
    locate_picture(file_9)#  ****   
    #img_9 = pyautogui.locateOnScreen('compliance_14.png', confidence=0.9)
    #while img_9 == None:
        #img_9 = pyautogui.locateOnScreen('compliance_14.png')
        #time.sleep(1.0)
        #print("still haven't found the image 9")
    pyautogui.click(x=1397, y=863)#  ****   
    time.sleep(1.0)#  ****   
    locate_picture(file_10)#  ****   
    #img_10 = pyautogui.locateOnScreen('compliance_6.png', confidence=0.9)
    #while img_10 == None:
        #img_10 = pyautogui.locateOnScreen('compliance_6.png')
        #time.sleep(1.0)
        #print("still haven't found the image 10")
    pyautogui.click(x=947, y=582)#  ****   
    time.sleep(2.0)
    pyautogui.click(x=1503, y=235)
    time.sleep(1.0)
# Out:
# still haven't found the file: compliance_5.png
# still haven't found the file: compliance_5.png
# still haven't found the file: compliance_16.png
# still haven't found the file: compliance_16.png
# still haven't found the file: compliance_6.png
# still haven't found the file: compliance_6.png
# still haven't found the file: compliance_6.png
# still haven't found the file: compliance_6.png
# still haven't found the file: compliance_5.png
# still haven't found the file: compliance_16.png
# still haven't found the file: compliance_16.png
# still haven't found the file: compliance_6.png
# still haven't found the file: compliance_6.png
# still haven't found the file: compliance_6.png
# still haven't found the file: compliance_6.png
# still haven't found the file: compliance_5.png
# still haven't found the file: compliance_5.png
# still haven't found the file: compliance_16.png
# still haven't found the file: compliance_16.png
# still haven't found the file: compliance_6.png
# ...

# %%
import pyautogui
pyautogui.position()
# Out:
# Point(x=1503, y=235)

# %%
time.sleep(2.0)

pyautogui.alert("NF's emitidas.")
# Out:
# 'OK'

# %%
pyautogui.alert("Seu código abrirá a pagina de cópias dos números de NF'S")
time.sleep(2.0)
pyautogui.click(x=1711, y=204)
locate_picture(file_11)
time.sleep(1.0)
pyautogui.moveTo(x=198, y=202)
time.sleep(1.5)
pyautogui.click(x=229, y=249)
time.sleep(1.5)
locate_picture(file_12)
time.sleep(1.0)
# Out:
# still haven't found the file: compliance_2.png
# still haven't found the file: compliance_2.png
# still haven't found the file: compliance_2.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png

# %%
###FAZER A SITUAÇÃO NA HORA DE SALVAR AS NF’S NAS PROPOSTAS 
##*POIS O TEMPO DE DEMORAR FOR X VAI TER Q FECHAR ABA DO COMPLIANCE (IF P ISSO) 
#POIS O COMPLIANCE FECHA SOZINHO DPS DE UM TEMPO COMO INATIVO OUTRO PONTO É MELHORAR AS LOCALIZAÇÕES DE PASTAS,
#TALVEZ ATE EXCLUIR ESSA PARTE DA PROCESSO DE SALVAR AS PASTAS Q DEVEM TER AS NF’S, A GNT MSM MANUALMENTE FZR ISSO,
#SÓ FZR O FATO DE SALVAR DIRETO NA PROPOSTA, AI VALE A PENA, AGR SALVAR A PASTA ACHO Q PERDE MUITO E É MUITO PERIGOSO.###


time.sleep(2.0)
pyautogui.alert("A nova aba será aberta.")
time.sleep(2.0)
pyautogui.hotkey('ctrl', 't')
locate_picture(file_13)
pyperclip.copy(r"https://emsj.fa.us6.oraclecloud.com/fscmUI/faces/FuseWelcome?_afrLoop=40226538553136344&fnd=%3B%3B%3B%3Bfalse%3B256%3B%3B%3B&_adf.ctrl-state=bzzo0q2qr_698")
time.sleep(1.0)
pyautogui.hotkey('ctrl', 'v')
time.sleep(1.0)
pyautogui.press('enter')
locate_picture(file_14)
time.sleep(1.5)
pyautogui.click(x=1754, y=128)
time.sleep(1.5)
locate_picture(file_15)
time.sleep(1.5)
pyautogui.click(x=1408, y=408)
locate_picture(file_16)
time.sleep(1.5)
pyautogui.click(x=444, y=299)
time.sleep(2.0)
pyautogui.click(x=268, y=650)
time.sleep(2.0)
pyautogui.click(x=993, y=528)
time.sleep(2.0)
pyautogui.write('MIDIA')
time.sleep(2.0)
pyautogui.press('enter')
locate_picture(file_30)
pyautogui.click(x=905, y=634, clicks=3)
time.sleep(2.5)
#click_position(file_clicar_1) inutil pois não escrevo data poois n sei os dias das transações.
#time.sleep(1.5)inutil pois não escrevo data poois n sei os dias das transações.
#pyautogui.write(hoje)inutil pois não escrevo data poois n sei os dias das transações.
#time.sleep(1.5)inutil pois não escrevo data poois n sei os dias das transações.
pyautogui.click(x=181, y=27)
time.sleep(1.0)
# Out:
# still haven't found the file: google.png
# still haven't found the file: oracle_1.png
# still haven't found the file: oracle_1.png
# still haven't found the file: oracle_1.png
# still haven't found the file: oracle_3.png
# still haven't found the file: oracle_3.png
# still haven't found the file: oracle_3.png
# still haven't found the file: oracle_6.png
# still haven't found the file: oracle_6.png

# %%
time.sleep(2.0)
pyautogui.alert("Seu código irá iniciar a copia do número das NFs.")
import openpyxl
from openpyxl import load_workbook #(usado p mexer em plan já existentes)
planilha_nfs = load_workbook('BASE DE DADOS.NF_TESTE.xlsx')
aba_planilha = planilha_nfs['INFOS']

file_31 = 'oracle_click_2.png'


for i, transacao in enumerate (tabela["TRANSAÇÃO"]):
    rps = tabela.loc[i, "RPS"]
    pyautogui.click(x=372, y=552, clicks=2)
    time.sleep(1.5)
    pyautogui.write(str(rps))
    time.sleep(1.5)
    pyautogui.click(x=718, y=551, clicks=2)
    time.sleep(1.5)
    pyautogui.write(str(rps))
    time.sleep(1.5)
    pyautogui.click(x=1466, y=746)
    time.sleep(1.0)
    locate_picture(file_17)
    time.sleep(1.0)
    img_autorizada = pyautogui.locateOnScreen('img_autorizada.png', confidence=0.7)
    time.sleep(1.0)
    if img_autorizada == None:
        pyautogui.alert('NF não emitida')
        continue
    else:
        pass
    time.sleep(1.0)   
    pyautogui.click(x=1516, y=319)
    time.sleep(1.5)
    pyautogui.click(x=524, y=26)
    time.sleep(1.0)
    pyautogui.click(x=860, y=300)
    time.sleep(1.0)
    pyautogui.write(str(transacao)) 
    time.sleep(1.5)
    pyautogui.press('enter')
    time.sleep(3.5)
    pyautogui.click(x=95, y=373)
    locate_picture(file_18)          
    pyautogui.click(x=209, y=244)                
    time.sleep(2.5)
    locate_picture(file_31)
    time.sleep(1.5)
    x, y = pyautogui.locateCenterOnScreen(file_31, confidence = 0.7)
    time.sleep(1.0)
    pyautogui.moveTo(x, y , duration = 0.1)
    time.sleep(1.0)
    x += 70
    time.sleep(1.0)
    pyautogui.click(x, y)
    #click_position(file_clicar_2)
    #time.sleep(2.5)
    #pyautogui.click(x=183, y=578)
    #time.sleep(2.5)
    time.sleep(2.0)
    pyautogui.click(x=172, y=23)
    locate_picture(file_19)    
    pyautogui.click(x=885, y=530, clicks=2)
    time.sleep(2.0)         
    pyautogui.hotkey('ctrl', 'c')                
    time.sleep(2.0)
    valor = pyperclip.paste()
    #ou chamar a função parecida: 
        #def copy_clipboard():
        #pya.hotkey('ctrl', 'c')
        #time.sleep(0.5)  ---- ctrl-c is usually very fast but your program may execute faster
        #return pyperclip.paste() ---- I have to move and select the place that I wanna copy before calling this function.
    time.sleep(2.0)
    aba_planilha.cell(column = 8, row = i + 2, value = valor)#ou coluna 8 se não for
    time.sleep(2.0)
    planilha_nfs.save('BASE DE DADOS.NF_TESTE.xlsx')
    time.sleep(2.0)
    pyautogui.click(x=552, y=24)
    time.sleep(2.5)
    pyautogui.click(x=1582, y=754, clicks=2)
    time.sleep(2.0)
    pyautogui.hotkey('ctrl', 'v')
    time.sleep(2.0)
    pyautogui.hotkey('tab')
    time.sleep(2.0)
    pyautogui.click(x=1688, y=185)
    time.sleep(2.0)
    pyautogui.click(x=1675, y=216)
    time.sleep(2.0)
    pyautogui.click(x=1020, y=370)
    time.sleep(2.0)
    pyautogui.click(x=33, y=238)
    time.sleep(2.0)
    pyautogui.click(x=905, y=297, clicks=2)
    time.sleep(2.0)
    pyautogui.hotkey('del')
    time.sleep(2.0)
    pyautogui.click(x=184, y=26)
    time.sleep(2.0)
    pyautogui.click(x=1607, y=175)
    time.sleep(1.3)
    pyautogui.click(x=361, y=253)
    time.sleep(1.3)
    pyautogui.moveTo(x=920, y=768)
    time.sleep(2.0)
    pyautogui.click(x=361, y=253)
    time.sleep(1.0)
# Out:
# still haven't found the file: compliance_7.png
# still haven't found the file: compliance_7.png
# still haven't found the file: oracle_5.png
# still haven't found the file: oracle_5.png
# still haven't found the file: oracle_5.png
# still haven't found the file: compliance_7.png
# still haven't found the file: compliance_7.png
# still haven't found the file: oracle_5.png
# still haven't found the file: oracle_5.png
# still haven't found the file: compliance_7.png
# still haven't found the file: compliance_7.png
# still haven't found the file: oracle_5.png
# still haven't found the file: oracle_5.png
# still haven't found the file: compliance_7.png
# still haven't found the file: compliance_7.png
# still haven't found the file: oracle_5.png
# still haven't found the file: oracle_5.png
# still haven't found the file: compliance_7.png
# still haven't found the file: compliance_7.png
# still haven't found the file: oracle_5.png
# still haven't found the file: oracle_5.png
# ...

# %%
import pyautogui
pyautogui.position()
# Out:
# Point(x=361, y=253)

# %%
import pyautogui
pyautogui.position()
# Out:
# Point(x=361, y=253)

# %%
time.sleep(2.0)
pyautogui.alert('Seu código vai fechar a aba do oracle.')
time.sleep(1.5)
pyautogui.click(x=520, y=29)
time.sleep(1.5)
pyautogui.hotkey('ctrl', 'w')

# %%
time.sleep(2.0)
pyautogui.alert('Seu código irá começar a salvar pastas das propostas.')
time.sleep(1.5)
### da p abrir pastas diretamente com os codigos do modulo de (os).
###tem exemplos em outro arquivo PY nesses caminhos. dá para abrir toda vez que salvar
### as pastas ou salvar os caminhos e anexar numa outra carga p eu conseguir
###salvar esses caminhos nas cargas e automatizar na hora de anexar nas propostas.
###fechar com ctrl T (ou w - n lembro) e ai fico nessa rodagem


#path = os.path.realpath(r"\\hofsbrm\Gestao de Receitas\Faturamento\Transacional\Gerencial\Mídias BRMALLS\MÍDIAS DE PARCEIROS")
#os.startfile(path)

for propostas in tabela["PROPOSTA"]:
    time.sleep(1.5)
    pyautogui.click(x=780, y=1052)
    locate_picture(file_20)
    time.sleep(1.0)
    pyautogui.click(x=736, y=265)
    time.sleep(1.5)
    pyautogui.click(x=736, y=265)
    time.sleep(1.5)
    pyautogui.click(x=736, y=265)
    time.sleep(1.5)
    pyautogui.click(x=736, y=265)
    time.sleep(1.5)
    pyautogui.click(x=736, y=265)
    time.sleep(1.5)
    pyautogui.click(x=170, y=402)
    time.sleep(1.5)
    pyautogui.moveTo(x=1795, y=96)
    time.sleep(1.5)
    pyautogui.click(x=1795, y=96)
    time.sleep(1.0)
    pyautogui.write(str(propostas))
    time.sleep(1.5)
    pyautogui.press('enter')
    time.sleep(1.5)
    locate_picture(file_21)
    time.sleep(1.0)
    pyautogui.click(button='right', x=976, y=163)
    time.sleep(1.5)
    locate_picture(file_22)
    pyautogui.click(x=1056, y=245)
    time.sleep(1.0)
    pyautogui.hotkey('ctrl', 'w')
    time.sleep(1.0)
    
    
####muitas coisas a melhorar na hora de salvar, seja p achar pastas, mexer nas pastas e mexer no arquivo que salva
#### as nf's. muitas melhorias lá.
###além, de claro, criar o projeto de salvar diretamente na proposta.

### da p abrir pastas diretamente com os codigos do modulo de (os).
###tem exemplos em outro arquivo PY nesses caminhos. dá para abrir toda vez que salvar
### as pastas ou salvar os caminhos e anexar numa outra carga p eu conseguir
###salvar esses caminhos nas cargas e automatizar na hora de anexar nas propostas.
###fechar com ctrl T (ou w - n lembro) e ai fico nessa rodagem
# Out:
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# still haven't found the file: pasta_2.png
# ...

# %%
time.sleep(2.0)
pyautogui.alert('Pastas salvas.')
time.sleep(1.0)
pyautogui.hotkey('ctrl', 'w')
time.sleep(1.0)

# %%
#pôr os cnpjs sem barras, pontos e hífens, pois no sistema do compliance é necessário.
def corrigir_cnpjs(cnpj):
    cnpj = cnpj.replace('/','').replace('-','').replace('.','')
    return cnpj
#ignorar possíveis espaços no dataframe que podem interferir na descrição da NF.
def corrigir_tabs(tabs):
    tabs = tabs.replace('\t',' ').replace('\n',' ').replace('\r', ' ').replace('\0', ' ').replace('\a', ' ').replace('\b', ' ').replace('\f', ' ')
    return tabs#essa linha de codigo funciona mesmo se por ventura escreverem algo desses caracteres lá dentro.
                #ele so funcionara qnd de fato ele ''possivelmente escrevesse um tab na hrda descriçao mesmo''
                #se manualmente eu escrevi algo disso, como por exemplo em uma descrição é possivel ter
                #\0, ele não vai usar o replace.

#formatar valores por milhar de acordo com o sistema do compliance.
def formatar(valor):
    return "{:,.2f}".format(valor)



tabela = pd.read_excel("BASE DE DADOS.NF_TESTE.xlsx")

display(tabela)#antes da funções de formatação

tabela['CNPJ'] = tabela['CNPJ'].astype(str)

tabela['NF'] = tabela['NF'].astype(str)

tabela['CNPJ'] = tabela['CNPJ'].apply(corrigir_cnpjs)

tabela['VALOR'] = tabela['VALOR'].apply(formatar)

tabela['DESCRIÇÃO NF'] = tabela['DESCRIÇÃO NF'].apply(corrigir_tabs)#ESSA É A NOVA FUNÇÃO P TIRAR O \T Q AS VEZES VEM.


display(tabela)

print('-' * 15)

print(tabela.info())
# Out:
#    CODIGO    RPS     VALOR                CNPJ  \
# 0  172501  11240   2272.62  44.810.398/0001-05
# 1  172501  11683   5247.12  03.783.850/0001-00
# 2  172501  11771  32666.67  34.647.363/0002-16
# 3  172501  11846  18229.00  07.639.431/0001-41
# 4  172501  10958  14000.00  37.526.019/0002-67
# 5  172501  11756   6015.34  62.596.408/0051-94
# 6  172501  11751  27900.00  34.075.739/0001-84
# 7  172501  11766   6781.87  05.423.963/0163-87
# 8  172501  11758   5359.20  48.628.366/0001-36
#
#                                         DESCRIÇÃO NF  TRANSAÇÃO  PROPOSTA  \
# 0  MIDIA DIGITAL - STEFANINI - PEDIDO DE INSERCAO...    1886033    134287
# 1  MIDIA DIGITAL - SENAI - REF PI:020416 - SHOPPI...    1944035    134683
# 2  MIDIA DIGITAL - PB CURSO - CARTA ACORDO - SHOP...    1965033    135161
# 3   MIDIA DIGITAL - SESI - REF PI: 9684 - SHOPPIN...    1974033    135298
# 4  CAMPANHA: QUINTAL SESC DADOS BANCARIOS: AG: 30...    1848042    133643
# ...

# %%
time.sleep(2.0)
pyautogui.alert("O Código de salvar as NF'S iniciará")
time.sleep(1.0)

####muitas coisas a melhorar na hora de salvar, seja p achar pastas, mexer nas pastas e mexer no arquivo que salva
#### as nf's. muitas melhorias lá.
###além, de claro, criar o projeto de salvar diretamente na proposta.


import datetime

date = datetime.date.today()

mes_hoje = date.month

year_number = date.year

year_number = str(year_number)

short_year = year_number[-2:]

if mes_hoje == 1:
    mes_hoje = 'JAN'
elif mes_hoje == 2:
    mes_hoje = 'FEV'
elif mes_hoje == 3:
    mes_hoje = 'MAR'
elif mes_hoje == 4:
    mes_hoje = 'ABR'
elif mes_hoje == 5:
    mes_hoje = 'MAI'
elif mes_hoje == 6:
    mes_hoje = 'JUN'
elif mes_hoje == 7:
    mes_hoje = 'JUL'
elif mes_hoje == 8:
    mes_hoje = 'AGO'
elif mes_hoje == 9:
    mes_hoje = 'SET'
elif mes_hoje == 10:
    mes_hoje = 'OUT'
elif mes_hoje == 11:
    mes_hoje = 'NOV'
elif mes_hoje == 12:
    mes_hoje = 'DEZ'
    
file_clicar_4 = 'NF_click_2.png'

time.sleep(1)
pyautogui.press('win')
time.sleep(1.5)
pyautogui.write('google')
time.sleep(1.5)
pyautogui.press('enter')
locate_picture(file_1)
pyperclip.copy(r"https://brmalls.compliancefiscal.com.br/complianceEnterpriseServer/login.seam?cid=169")
time.sleep(1.0)
pyautogui.hotkey('ctrl', 'v')
time.sleep(1.0)
pyautogui.press('enter')
locate_picture(file_2)
pyautogui.click(x=947, y=620)
time.sleep(1.0)
locate_picture(file_3)
pyautogui.moveTo(x=285, y=198)
time.sleep(1.0)
pyautogui.moveTo(x=198, y=202)
time.sleep(1.5)
pyautogui.click(x=229, y=249)
time.sleep(1.5)
locate_picture(file_12)
time.sleep(1.0)

###COMEÇAR A GRAVAR HORÁRIO E GRAVAR TELA DE 
#QUANDO ROBO TIVER RODANDO P PEGAR OS MOTIVOS DOS POSSÍVEIS ERRROS QUE ACONTECEM NO ROBO.###

for i, propostas in enumerate (tabela["PROPOSTA"]):
    rps = tabela.loc[i, "RPS"]
    nota = tabela.loc[i, "NF"]
    time.sleep(1.5)
    pyautogui.click(x=372, y=552, clicks=2)
    time.sleep(1.5)
    pyautogui.write(str(rps))
    time.sleep(1.5)
    pyautogui.press('tab')
    time.sleep(2.0)
    pyautogui.write(str(rps))
    time.sleep(2.0)
    pyautogui.click(x=1466, y=746)
    locate_picture(file_23)
    pyautogui.click(x=1517, y=322)
    locate_picture(file_24)
    pyautogui.click(x=1548, y=897)
    locate_picture(file_25)
    pyautogui.click(x=908, y=163)
    locate_picture(file_26)
    pyautogui.click(x=1478, y=938)
    locate_picture(file_27)
    pyautogui.click(x=980, y=405, clicks = 3)
    time.sleep(1.5)
    pyautogui.press('del')
    time.sleep(1.5)
    pyautogui.write(str(propostas) + ' (PROPOSTA) ' )
    time.sleep(1.5)
    pyautogui.write('NF - ')
    time.sleep(1.5)
    pyautogui.write(nota)
    time.sleep(1.5)
    pyautogui.write(" " + mes_hoje + "." + short_year)
    time.sleep(2.0)
    pyautogui.click(x=940, y=479, clicks = 3)
    time.sleep(1.5)
    pyautogui.press('del')
    time.sleep(1.5)
    pyperclip.copy(r"\\hofsbrm\Gestao de Receitas\Faturamento\Transacional\Gerencial\Mídias BRMALLS\MÍDIAS DE PARCEIROS\NF'S FUTURAS\JANEIRO - 22")
    time.sleep(1.0)
    pyautogui.hotkey('ctrl', 'v')         
    time.sleep(1.0)
    pyautogui.click(x=1197, y=935)
    locate_picture(file_28)
    pyautogui.hotkey('ctrl', 'w')
    time.sleep(2.0)
    click_position(file_clicar_4)
    #pyautogui.click(x=1225, y=1047)          
    time.sleep(1.5)
    pyautogui.click(x=1199, y=926)
    time.sleep(2.0)
    pyautogui.hotkey('alt', 'tab')
    locate_picture(file_29)
    pyautogui.hotkey('ctrl', 'w')
    time.sleep(1.3)
    pyautogui.click(x=1602, y=172)
    time.sleep(1.3)
    pyautogui.click(x=361, y=253)
    time.sleep(1.3)
    pyautogui.moveTo(x=920, y=768)
    time.sleep(2.0)
    pyautogui.click(x=361, y=253)
    time.sleep(1.0)
###COMEÇAR A GRAVAR HORÁRIO E GRAVAR TELA DE 
#QUANDO ROBO TIVER RODANDO P PEGAR OS MOTIVOS DOS POSSÍVEIS ERRROS QUE ACONTECEM NO ROBO.###
    
    
###FAZER A SITUAÇÃO NA HORA DE SALVAR AS NF’S NAS PROPOSTAS 
##*POIS O TEMPO DE DEMORAR FOR X VAI TER Q FECHAR ABA DO COMPLIANCE (IF P ISSO) 
#POIS O COMPLIANCE FECHA SOZINHO DPS DE UM TEMPO COMO INATIVO OUTRO PONTO É MELHORAR AS LOCALIZAÇÕES DE PASTAS,
#TALVEZ ATE EXCLUIR ESSA PARTE DA PROCESSO DE SALVAR AS PASTAS Q DEVEM TER AS NF’S, A GNT MSM MANUALMENTE FZR ISSO,
#SÓ FZR O FATO DE SALVAR DIRETO NA PROPOSTA, AI VALE A PENA, AGR SALVAR A PASTA ACHO Q PERDE MUITO E É MUITO PERIGOSO.###
# Out:
# still haven't found the file: google.png
# still haven't found the file: compliance_1.png
# still haven't found the file: compliance_2.png
# still haven't found the file: compliance_2.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_4.png
# still haven't found the file: compliance_12.png
# still haven't found the file: compliance_12.png
# still haven't found the file: compliance_9.png
# still haven't found the file: compliance_9.png
# still haven't found the file: compliance_9.png
# still haven't found the file: NF_1.png
# still haven't found the file: NF_1.png
# still haven't found the file: NF_2.png
# still haven't found the file: NF_3.png
# still haven't found the file: NF_3.png
# still haven't found the file: NF_3.png
# still haven't found the file: NF_3.png
# ...

# %%
pyautogui.alert('Codigo finalizado.')
# Out:
# 'OK'

# %%
 pyautogui.position()
# Out:
# Point(x=959, y=635)

# %% [markdown]
# ##### time.sleep(1.5)
# pyautogui.alert('Seu código foi completamente finalizado')
